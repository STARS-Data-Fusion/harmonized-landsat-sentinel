# %%
from HLS import HLS2Connection

# %%
HLS_connection = HLS2Connection()
HLS_connection
# Out:
# [2024-10-30 18:18:51 INFO] HLS 2.0 working directory: /Users/gregoryhalverson/Projects/HLS
# [2024-10-30 18:18:51 INFO] HLS 2.0 download directory: /Users/gregoryhalverson/Projects/HLS/HLS2_download
# [2024-10-30 18:18:51 INFO] HLS 2.0 products directory: /Users/gregoryhalverson/Projects/HLS/HLS2_products
# HLS2CMRConnection(
# 	working_directory="/Users/gregoryhalverson/Projects/HLS",
# 	download_directory="/Users/gregoryhalverson/Projects/HLS/HLS2_download",
# 	products_directory="/Users/gregoryhalverson/Projects/HLS/HLS2_products",
# 	remote="None"
# )

# %%
HLS_connection.listing("11SPS", "2024-10-01", "2024-11-01")
# Out:
# [2024-10-30 18:20:30 INFO] started listing available HLS2 granules at tile 11SPS from 2024-10-01 to 2024-11-01
# [2024-10-30 18:20:30 INFO] searching HLSS30.v2.0, HLSL30.v2.0 at 11SPS from 2024-09-15 to 2024-11-01
# [2024-10-30 18:20:33 INFO] Currently storing 24 DataGranules for HLS2
# [2024-10-30 18:20:33 INFO] finished listing available HLS2 granules at tile 11SPS from 2024-10-01 to 2024-11-01 (2.52)
#       date_UTC   tile                                           sentinel  \
# 0   2024-10-01  11SPS                                                NaN
# 1   2024-10-02  11SPS                                                NaN
# 2   2024-10-03  11SPS  {'meta': {'concept-type': 'granule', 'concept-...
# 3   2024-10-04  11SPS                                                NaN
# 4   2024-10-05  11SPS                                                NaN
# 5   2024-10-06  11SPS                                                NaN
# ...
